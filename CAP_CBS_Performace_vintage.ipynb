# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_excel('DATA_CAP_CBS_Performace_2.xlsx')

# %%
df.head(2)
# Out:
#    AS_OF_DATE    CUST_ID      CUST_NAME    ACC_ID  BRANCH_CODE  BRANCH_DESC  \
# 0  31/10/2021  750928539  ยุภาวรรณ คำทา  19042299            1  สาขาคลองตัน
# 1  30/11/2021  750928539  ยุภาวรรณ คำทา  19042299            1  สาขาคลองตัน
#
#    PROD_TYPE       PROD_TYPE_DESC  CREDIT_LIMIT  LEDGER_BALANCE CUST_CLASS  \
# 0       7200  สินเชื่อเพื่ออุปโภค         80000        80000.00         B1
# 1       7200  สินเชื่อเพื่ออุปโภค         80000        78048.77         B1
#
#   DATA_SOURCE RELIGION CORE_RELIGION MUSLIM_DEF         ID_NO  ACC_CLASS  \
# 0         CBS     พุทธ       2_อื่นๆ        NaN  1.230300e+12        1.0
# 1         CBS     พุทธ       2_อื่นๆ        NaN  1.230300e+12        1.0
#
#   ISIC_NEW_FINAL_BY_OIS ISIC_GROUP_NEW_BY_OIS  COUNT_CIF_22  COUNT_CIF_ALL  \
# 0                241041                  22.7             1              1
# 1                241041                  22.7             1              1
#
# ...

# %%
a = pd.pivot_table(df,values='ACC_ID', index='MOB',columns='EVER_DQ_X',aggfunc='count')

# %%
a
# Out:
# EVER_DQ_X  1.0
# MOB
# 0            1
# 1            8
# 2           12
# 3           11
# 4           12
# 5           14
# 6           14
# 7           15
# 8           17
# 9           19
# 10          17
# 11          14
# 12          12
# 13           7
# 14           1
